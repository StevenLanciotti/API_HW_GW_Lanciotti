# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint
import json

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 588

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

i = 1
city_name=[]
cloudiness=[]
country=[]
date = []
humidity=[]
lat=[]
lng=[]
max_temp=[]
wind_speed=[]

# pp = pprint.PrettyPrinter(indent=4)
# response = requests.get(query_url + cities[1]).json()
        
# print(requests.get(query_url + cities[1]).status_code)
# city_name.append(response['name'])
# cloudiness.append(response['clouds']['all'])
# country.append(response['sys']['country'])
# date.append(response['dt'])
# humidity.append(response['main']['humidity'])
# lat.append(response['coord']['lat'])
# lng.append(response['coord']['lon'])
# max_temp.append(response['main']['temp_max'])
# wind_speed.append(response['wind']['speed'])

# pp.pprint(response)

print(f"Beginning Data Retrieval:")
print(f"--------------------------")
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        print(f"Processing Record #{i} | {city}")
        i += 1
        time.sleep(1)

    except:
        print(f"City not found. Skipping...")
        time.sleep(1)
        
print(f"--------------------------")
print(f"Data Retrieval Complete")
print(f"--------------------------")
# Out:
# Beginning Data Retrieval:
# --------------------------
# Processing Record #1 | yellowknife
# Processing Record #2 | sistranda
# Processing Record #3 | busselton
# Processing Record #4 | den helder
# Processing Record #5 | ndjole
# Processing Record #6 | saint-augustin
# Processing Record #7 | port alfred
# Processing Record #8 | ushuaia
# Processing Record #9 | cape town
# Processing Record #10 | pacaembu
# Processing Record #11 | hermanus
# Processing Record #12 | kapaa
# Processing Record #13 | cortez
# Processing Record #14 | hithadhoo
# Processing Record #15 | klaksvik
# Processing Record #16 | altay
# Processing Record #17 | vaini
# Processing Record #18 | chuy
# Processing Record #19 | thompson
# Processing Record #20 | albany
# Processing Record #21 | new norfolk
# Processing Record #22 | east london
# City not found. Skipping...
# Processing Record #23 | turukhansk
# Processing Record #24 | wanaka
# Processing Record #25 | jamestown
# Processing Record #26 | kodiak
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({'City':city_name,
                         'Cloudiness':cloudiness,
                         'Country':country,
                         'Date':date,
                         'Humidity':humidity,
                         'Lat':lat,
                         'Lng':lng,
                         'Max Temp':max_temp,
                         'Wind Speed':wind_speed})
weather_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Yellowknife          20      CA  1573399653        83  62.45 -114.38
# 1    Sistranda          75      NO  1573399654        73  63.73    8.83
# 2    Busselton           0      AU  1573399655        52 -33.64  115.35
# 3   Den Helder          89      NL  1573399657        76  52.96    4.76
# 4       Ndjole         100      GA  1573399658        93  -0.18   10.76
#
#    Max Temp  Wind Speed
# 0      -3.0        3.36
# 1      27.0       10.29
# 2      61.0       12.37
# 3      50.0       13.87
# 4      76.8        2.73

# %%
print(f'Max Latitude: {weather_df["Lat"].max()}')
print(f'Min Latitude: {weather_df["Lat"].min()}')
print(f'Max Temp: {weather_df["Max Temp"].max()}')
print(f'Min Temp: {weather_df["Max Temp"].min()}')
print(f'Max Humidity: {weather_df["Humidity"].max()}')
print(f'Min Humidity: {weather_df["Humidity"].min()}')
print(f'Max Cloudiness: {weather_df["Cloudiness"].max()}')
print(f'Min Cloudiness: {weather_df["Cloudiness"].min()}')
print(f'Max Wind Speed: {weather_df["Wind Speed"].max()}')
print(f'Min Wind Speed: {weather_df["Wind Speed"].min()}')
# Out:
# Max Latitude: 78.22
# Min Latitude: -54.81
# Max Temp: 103.33
# Min Temp: -23.81
# Max Humidity: 100
# Min Humidity: 8
# Max Cloudiness: 100
# Min Cloudiness: 0
# Max Wind Speed: 51.67
# Min Wind Speed: 0.09

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], marker="o", facecolors="red", edgecolors="black")
plt.ylim(-25,105)
plt.xlim(-50,80)
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title("City Latitude vs Max Temperature")
# Out:
# Text(0.5, 1.0, 'City Latitude vs Max Temperature')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Humidity'], marker="o", facecolors="red", edgecolors="black")
plt.ylim(0,105)
plt.xlim(-50,80)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity")
# Out:
# Text(0.5, 1.0, 'City Latitude vs Humidity')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], marker="o", facecolors="red", edgecolors="black")
plt.ylim(-5,105)
plt.xlim(-50,80)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness")
# Out:
# Text(0.5, 1.0, 'City Latitude vs Cloudiness')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], marker="o", facecolors="red", edgecolors="black")
plt.ylim(-5,55)
plt.xlim(-50,80)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs Wind Speed")
# Out:
# Text(0.5, 1.0, 'City Latitude vs Wind Speed')
